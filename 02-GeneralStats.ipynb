# %% [markdown]
# # General Divvy Bike Share Analysis
# This notebook is used for processing and cleaning Divvy Bike Sharing data for the September 2022 data set.

# %%
import pandas as pd
import plotly.graph_objects as go
import os

# %%
## Create file location
ROOT = os.getcwd()
SAVE_FILES = os.path.join(ROOT, "DATA")
SAVE_FILES
# Out:
# 'C:\\Users\\Nicholas\\Desktop\\Masters - Classes\\MSDS436\\Final\\MSDS436-FINAL\\DATA'

# %%
df = pd.read_csv(os.path.join(SAVE_FILES, "202209_divvy_distance.csv"))
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  2FD3F90EDCE2ACD9   classic_bike  2022-09-01 19:39:15  2022-09-01 19:46:45
# 1  EE62794A94F80A83   classic_bike  2022-09-01 06:53:41  2022-09-01 07:02:54
# 2  56FD4B364747F270  electric_bike  2022-09-01 11:25:21  2022-09-01 11:28:33
# 3  BD4D6AC842CDF729   classic_bike  2022-09-01 07:46:03  2022-09-01 08:05:36
# 4  2E0E8C378865C01A  electric_bike  2022-09-01 09:55:31  2022-09-01 10:12:27
#
#                    start_station_name start_station_id  \
# 0           Southport Ave & Roscoe St            13071
# 1          LaSalle St & Washington St            13006
# 2  N Sheffield Ave & W Wellington Ave          20256.0
# 3         Racine Ave & Wrightwood Ave     TA1309000059
# 4               Wabash Ave & Adams St     KA1503000015
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0             Broadway & Cornelia Ave          13278  41.943739 -87.664020
# 1                  Wells St & Polk St         SL-011  41.882664 -87.632530
# 2      Southport Ave & Wellington Ave   TA1307000006  41.940000 -87.650000
# 3  DuSable Lake Shore Dr & North Blvd         LF-005  41.928887 -87.658971
# 4          Wood St & Taylor St (Temp)          13285  41.879373 -87.625492
#
#      end_lat    end_lng member_casual started_at_clean  duration (s)  \
# 0  41.945529 -87.646439        member       2022-09-01         481.9
# 1  41.872732 -87.633516        casual       2022-09-01         395.0
# 2  41.935733 -87.663576        casual       2022-09-01         411.5
# 3  41.911722 -87.626804        casual       2022-09-01         948.8
# 4  41.869265 -87.673731        member       2022-09-01        1275.1
#
#    distance (m)
# 0        1669.2
# 1        1358.8
# 2        1595.7
# 3        3643.8
# 4        5104.7

# %% [markdown]
# ## Type conversion

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# started_at_clean       object
# duration (s)          float64
# distance (m)          float64
# dtype: object

# %% [markdown]
# ### Trip duration

# %%
df['started_at'] = pd.to_datetime(df['started_at']) # Ride start date and time
df['ended_at'] = pd.to_datetime(df['ended_at']) # Ride end data and time
df['ride_duration'] = (df['ended_at'] - df['started_at']).astype('timedelta64[s]') / 60 # Ride duration in minutes

# %% [markdown]
# ### Time

# %%
df['day_of_week'] = df['started_at'].dt.day_name() # Name of day 
df['day_no'] = df['started_at'].dt.dayofweek # Day number, will be used for sorting in visualizations

df['month_of_year'] = df['started_at'].dt.month_name() # Name of month
df['month_no'] = df['started_at'].dt.month # Month number, will be used for sorting in visualizations

df['hour'] = df['started_at'].dt.hour # Hour bike ride starts at

# %% [markdown]
# ### Round lat & long

# %%
df = df.round({'start_lat': 3, 'start_lng': 3, 'end_lat': 3, 'end_lng': 3})
display(len(df))
display(df.head())
# Out:
# 150000
#             ride_id  rideable_type          started_at            ended_at  \
# 0  2FD3F90EDCE2ACD9   classic_bike 2022-09-01 19:39:15 2022-09-01 19:46:45
# 1  EE62794A94F80A83   classic_bike 2022-09-01 06:53:41 2022-09-01 07:02:54
# 2  56FD4B364747F270  electric_bike 2022-09-01 11:25:21 2022-09-01 11:28:33
# 3  BD4D6AC842CDF729   classic_bike 2022-09-01 07:46:03 2022-09-01 08:05:36
# 4  2E0E8C378865C01A  electric_bike 2022-09-01 09:55:31 2022-09-01 10:12:27
#
#                    start_station_name start_station_id  \
# 0           Southport Ave & Roscoe St            13071
# 1          LaSalle St & Washington St            13006
# 2  N Sheffield Ave & W Wellington Ave          20256.0
# 3         Racine Ave & Wrightwood Ave     TA1309000059
# 4               Wabash Ave & Adams St     KA1503000015
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0             Broadway & Cornelia Ave          13278     41.944    -87.664
# 1                  Wells St & Polk St         SL-011     41.883    -87.633
# 2      Southport Ave & Wellington Ave   TA1307000006     41.940    -87.650
# 3  DuSable Lake Shore Dr & North Blvd         LF-005     41.929    -87.659
# 4          Wood St & Taylor St (Temp)          13285     41.879    -87.625
#
#    ...  member_casual  started_at_clean duration (s) distance (m)  \
# 0  ...         member        2022-09-01        481.9       1669.2
# 1  ...         casual        2022-09-01        395.0       1358.8
# 2  ...         casual        2022-09-01        411.5       1595.7
# 3  ...         casual        2022-09-01        948.8       3643.8
# 4  ...         member        2022-09-01       1275.1       5104.7
#
#    ride_duration  day_of_week  day_no month_of_year  month_no hour
# 0       7.500000     Thursday       3     September         9   19
# 1       9.216667     Thursday       3     September         9    6
# 2       3.200000     Thursday       3     September         9   11
# 3      19.550000     Thursday       3     September         9    7
# 4      16.933333     Thursday       3     September         9    9
#
# [5 rows x 22 columns]

# %% [markdown]
# ### General Data Cleaning
# - Ride duation should be a positive number.
# - Get rid of data with missing latitude and/or longitude information.

# %%
df = df[df['ride_duration'] > 0]
df = df[df['end_lat'].notna()]
df = df[df['end_lng'].notna()]

display(len(df))
display(df.head())
# Out:
# 149995
#             ride_id  rideable_type          started_at            ended_at  \
# 0  2FD3F90EDCE2ACD9   classic_bike 2022-09-01 19:39:15 2022-09-01 19:46:45
# 1  EE62794A94F80A83   classic_bike 2022-09-01 06:53:41 2022-09-01 07:02:54
# 2  56FD4B364747F270  electric_bike 2022-09-01 11:25:21 2022-09-01 11:28:33
# 3  BD4D6AC842CDF729   classic_bike 2022-09-01 07:46:03 2022-09-01 08:05:36
# 4  2E0E8C378865C01A  electric_bike 2022-09-01 09:55:31 2022-09-01 10:12:27
#
#                    start_station_name start_station_id  \
# 0           Southport Ave & Roscoe St            13071
# 1          LaSalle St & Washington St            13006
# 2  N Sheffield Ave & W Wellington Ave          20256.0
# 3         Racine Ave & Wrightwood Ave     TA1309000059
# 4               Wabash Ave & Adams St     KA1503000015
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0             Broadway & Cornelia Ave          13278     41.944    -87.664
# 1                  Wells St & Polk St         SL-011     41.883    -87.633
# 2      Southport Ave & Wellington Ave   TA1307000006     41.940    -87.650
# 3  DuSable Lake Shore Dr & North Blvd         LF-005     41.929    -87.659
# 4          Wood St & Taylor St (Temp)          13285     41.879    -87.625
#
#    ...  member_casual  started_at_clean duration (s) distance (m)  \
# 0  ...         member        2022-09-01        481.9       1669.2
# 1  ...         casual        2022-09-01        395.0       1358.8
# 2  ...         casual        2022-09-01        411.5       1595.7
# 3  ...         casual        2022-09-01        948.8       3643.8
# 4  ...         member        2022-09-01       1275.1       5104.7
#
#    ride_duration  day_of_week  day_no month_of_year  month_no hour
# 0       7.500000     Thursday       3     September         9   19
# 1       9.216667     Thursday       3     September         9    6
# 2       3.200000     Thursday       3     September         9   11
# 3      19.550000     Thursday       3     September         9    7
# 4      16.933333     Thursday       3     September         9    9
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Drop outliers
# Drop any rides shorter than ~0.5 minutes or longer than 540 minutes.

# %%
df = df[(df.ride_duration <= df.ride_duration.quantile(.999)) & (df.ride_duration >= df.ride_duration.quantile(.01))]

display(len(df))
display(df.head())
# Out:
# 148360
#             ride_id  rideable_type          started_at            ended_at  \
# 0  2FD3F90EDCE2ACD9   classic_bike 2022-09-01 19:39:15 2022-09-01 19:46:45
# 1  EE62794A94F80A83   classic_bike 2022-09-01 06:53:41 2022-09-01 07:02:54
# 2  56FD4B364747F270  electric_bike 2022-09-01 11:25:21 2022-09-01 11:28:33
# 3  BD4D6AC842CDF729   classic_bike 2022-09-01 07:46:03 2022-09-01 08:05:36
# 4  2E0E8C378865C01A  electric_bike 2022-09-01 09:55:31 2022-09-01 10:12:27
#
#                    start_station_name start_station_id  \
# 0           Southport Ave & Roscoe St            13071
# 1          LaSalle St & Washington St            13006
# 2  N Sheffield Ave & W Wellington Ave          20256.0
# 3         Racine Ave & Wrightwood Ave     TA1309000059
# 4               Wabash Ave & Adams St     KA1503000015
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0             Broadway & Cornelia Ave          13278     41.944    -87.664
# 1                  Wells St & Polk St         SL-011     41.883    -87.633
# 2      Southport Ave & Wellington Ave   TA1307000006     41.940    -87.650
# 3  DuSable Lake Shore Dr & North Blvd         LF-005     41.929    -87.659
# 4          Wood St & Taylor St (Temp)          13285     41.879    -87.625
#
#    ...  member_casual  started_at_clean duration (s) distance (m)  \
# 0  ...         member        2022-09-01        481.9       1669.2
# 1  ...         casual        2022-09-01        395.0       1358.8
# 2  ...         casual        2022-09-01        411.5       1595.7
# 3  ...         casual        2022-09-01        948.8       3643.8
# 4  ...         member        2022-09-01       1275.1       5104.7
#
#    ride_duration  day_of_week  day_no month_of_year  month_no hour
# 0       7.500000     Thursday       3     September         9   19
# 1       9.216667     Thursday       3     September         9    6
# 2       3.200000     Thursday       3     September         9   11
# 3      19.550000     Thursday       3     September         9    7
# 4      16.933333     Thursday       3     September         9    9
#
# [5 rows x 22 columns]

# %%
# Drop columns that are not needed
df.drop(['ride_id', 'start_station_name', 'start_station_id', 'end_station_name', 'end_station_id' ], axis=1, inplace=True)

# %%
# By Day
rd_by_day = df.groupby(['day_no', 'day_of_week', 'member_casual']).agg({'ride_duration' : ['min','max', 'mean', 'median']})
rd_by_day.columns = rd_by_day.columns.to_flat_index()
# rd_by_day.head()


#By Month
rd_by_month = df.groupby(['month_no', 'month_of_year', 'member_casual']).agg({'ride_duration' : ['min','max', 'mean', 'median']})
rd_by_month.columns = rd_by_month.columns.to_flat_index()
rd_by_month.head()
# Out:
#                                       (ride_duration, min)  \
# month_no month_of_year member_casual
# 9        September     casual                         0.45
#                        member                         0.45
#
#                                       (ride_duration, max)  \
# month_no month_of_year member_casual
# 9        September     casual                   325.750000
#                        member                   324.216667
#
#                                       (ride_duration, mean)  \
# month_no month_of_year member_casual
# 9        September     casual                     20.603445
#                        member                     12.298168
#
#                                       (ride_duration, median)
# month_no month_of_year member_casual
# 9        September     casual                       12.750000
#                        member                        9.183333

# %%
num_rides = df[['month_no', 'month_of_year','day_no', 'day_of_week','hour','member_casual']].drop_duplicates().reset_index()
num_rides.rename(columns={num_rides.columns[0]: "cnt"}, inplace=True)

num_rides
# Out:
#        cnt  month_no month_of_year  day_no day_of_week  hour member_casual
# 0        0         9     September       3    Thursday    19        member
# 1        1         9     September       3    Thursday     6        casual
# 2        2         9     September       3    Thursday    11        casual
# 3        3         9     September       3    Thursday     7        casual
# 4        4         9     September       3    Thursday     9        member
# ..     ...       ...           ...     ...         ...   ...           ...
# 331  30320         9     September       2   Wednesday    23        member
# 332  30475         9     September       2   Wednesday     1        casual
# 333  30620         9     September       2   Wednesday     3        casual
# 334  30762         9     September       2   Wednesday     2        casual
# 335  31606         9     September       2   Wednesday     4        casual
#
# [336 rows x 7 columns]

# %%
df_paths = df[['start_lat','start_lng','end_lat', 'end_lng', 'member_casual']].drop_duplicates().reset_index()
df_paths.reset_index(inplace=True)
df_paths.rename(columns={df_paths.columns[0]: "cnt"}, inplace=True)

df_paths = df_paths[df_paths['cnt']>100] # Filter out the most popular paths

# Generate two data frames for popular paths: Casual riders and members
df_paths_c = df_paths[df_paths['member_casual'] == 'casual'].reset_index()
df_paths_m = df_paths[df_paths['member_casual'] == 'member'].reset_index()

# %%
df_paths.to_csv('webpage/DATA/202209_divvy_paths.csv', index=False)
df_paths_c[:10000].to_csv('webpage/DATA/202209_divvy_cas.csv', index=False)
df_paths_m[:10000].to_csv('webpage/DATA/202209_divvy_mem.csv', index=False)

# %%
fig = go.Figure()

#Plot casual riders' popular paths in red.
for i in range(len(df_paths_c[:1000])):
    fig.add_trace(
        go.Scattergeo(
            locationmode = 'USA-states',
            lon = [df_paths_c['start_lng'][i], df_paths_c['end_lng'][i]],
            lat = [df_paths_c['start_lat'][i], df_paths_c['end_lat'][i]],
            mode = 'lines',
            line = dict(width = 1,color = 'red'),
            opacity = float(df_paths_c['cnt'][i]) / float(df_paths['cnt'].max()),
        )
    )

#Plot members' popular paths in blue.
for i in range(len(df_paths_m[:1000])):
    fig.add_trace(
        go.Scattergeo(
            locationmode = 'USA-states',
            lon = [df_paths_m['start_lng'][i], df_paths_m['end_lng'][i]],
            lat = [df_paths_m['start_lat'][i], df_paths_m['end_lat'][i]],
            mode = 'lines',
            line = dict(width = 1,color = 'blue'),
            opacity = float(df_paths_m['cnt'][i]) / float(df_paths['cnt'].max()),
        )
    )   

fig.update_layout(
    title_text = 'Divvy Bike Sharing Popular Paths',
    showlegend = False,
    geo = dict(
        scope = 'north america',
        projection_type = 'azimuthal equal area',
        showland = True,
        showsubunits = True,
        landcolor = 'rgb(243, 243, 243)',
        countrycolor = 'rgb(204, 204, 204)',
        fitbounds = 'locations',
    ),
)

fig.show()
# Out:
# <div>                            <div id="2a51e5dc-c4a3-4805-b864-eb13778d0e47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a51e5dc-c4a3-4805-b864-eb13778d0e47")) {                    Plotly.newPlot(                        "2a51e5dc-c4a3-4805-b864-eb13778d0e47",                        [{"lat":[41.962,41.961],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.655,-87.676],"mode":"lines","opacity":0.0015019257364640801,"type":"scattergeo"},{"lat":[41.895,41.883],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.618,-87.641],"mode":"lines","opacity":0.0015167962883102593,"type":"scattergeo"},{"lat":[41.918,41.941],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.636,-87.639],"mode":"lines","opacity":0.0015465373920026172,"type":"scattergeo"},{"lat":[41.931,41.929],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.639,-87.664],"mode":"lines","opacity":0.0015614079438487963,"type":"scattergeo"},{"lat":[41.887,41.922],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.626,-87.644],"mode":"lines","opacity":0.0016208901512335123,"type":"scattergeo"},{"lat":[41.969,41.969],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.658,-87.658],"mode":"lines","opacity":0.0016357607030796912,"type":"scattergeo"},{"lat":[41.922,41.925],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.644,-87.666],"mode":"lines","opacity":0.0016506312549258704,"type":"scattergeo"},{"lat":[41.903,41.878],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.632,-87.641],"mode":"lines","opacity":0.0016655018067720493,"type":"scattergeo"},{"lat":[41.903,41.914],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.634,-87.649],"mode":"lines","opacity":0.0016952429104644074,"type":"scattergeo"},{"lat":[41.903,41.903],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.631,-87.631],"mode":"lines","opacity":0.0017249840141567653,"type":"scattergeo"},{"lat":[41.878,41.871],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.624,-87.626],"mode":"lines","opacity":0.0017398545660029443,"type":"scattergeo"},{"lat":[41.92,41.922],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.649,-87.644],"mode":"lines","opacity":0.0017695956696953024,"type":"scattergeo"},{"lat":[41.89,41.889],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.634,-87.627],"mode":"lines","opacity":0.0017844662215414813,"type":"scattergeo"},{"lat":[41.893,41.941],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.617,-87.639],"mode":"lines","opacity":0.0018142073252338394,"type":"scattergeo"},{"lat":[41.886,41.881],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.625,-87.624],"mode":"lines","opacity":0.0018290778770800183,"type":"scattergeo"},{"lat":[41.916,41.896],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.687,-87.682],"mode":"lines","opacity":0.0018736895326185554,"type":"scattergeo"},{"lat":[41.878,41.879],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.644,-87.64],"mode":"lines","opacity":0.0019629128436956297,"type":"scattergeo"},{"lat":[41.948,41.933],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.664,-87.648],"mode":"lines","opacity":0.0020372656029265246,"type":"scattergeo"},{"lat":[41.954,41.954],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.664,-87.648],"mode":"lines","opacity":0.0021116183621574195,"type":"scattergeo"},{"lat":[41.964,41.885],"line":{"color":"red","width":1},"locationmode":"USA-states","lon":[-87.638,-87.628],"mode":"lines","opac ...

# %%
df_paths_m['start_lng']
