# %% [markdown]
# # Pulling data from the Divvy

# %% [markdown]
# ## Description
# We will need a programatic way to gather Divvy's monthly bike/trip data found on [thier portal](https://divvy-tripdata.s3.amazonaws.com/index.html). The data is uploaded on a monthly bases and it excludes trips that are taken by staff as they service and inspect the system; and any trips that were below 60 seconds in length (potentially false starts or users trying to re-dock a bike to ensure it was secure).

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
from bs4 import BeautifulSoup
import os
import requests
import zipfile
import io

# %% [markdown]
# ## Create file location

# %%
ROOT = os.getcwd()
SAVE_FILES = os.path.join(ROOT, "DATA")
SAVE_FILES
# Out:
# 'C:\\Users\\Nicholas\\Desktop\\Masters - Classes\\MSDS436\\Final\\DATA'

# %% [markdown]
# ## Pull Divvy Bike Data

# %% [markdown]
# ### Pull keys from website using BeautifulSoup

# %%
main_url = 'https://divvy-tripdata.s3.amazonaws.com'
page = requests.get(main_url)
soup = BeautifulSoup(page.content, 'html.parser')

print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <listbucketresult xmlns="http://s3.amazonaws.com/doc/2006-03-01/">
#  <name>
#   divvy-tripdata
#  </name>
#  <prefix>
#  </prefix>
#  <marker>
#  </marker>
#  <maxkeys>
#   1000
#  </maxkeys>
#  <istruncated>
#   false
#  </istruncated>
#  <contents>
#   <key>
#    202004-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2020-06-01T14:50:06.000Z
#   </lastmodified>
#   <etag>
#    "e7a221ace4629d53dcd73a62b314b567"
#   </etag>
#   <size>
#    3323572
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202005-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2020-06-01T14:50:09.000Z
#   </lastmodified>
#   <etag>
#    "606a191a00a58840ce8d3cf7d08556e4"
#   </etag>
#   <size>
#    7988821
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202006-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2020-07-06T00:31:49.000Z
#   </lastmodified>
#   <etag>
#    "e397c3a64e4f8d4cefe90736cce330eb"
#   </etag>
#   <size>
#    14732088
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202007-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2020-08-12T02:10:49.000Z
#   </lastmodified>
#   <etag>
#    "03907bf42f9d07b5b1f07e2aac487a04-2"
#   </etag>
#   <size>
#    23621786
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202008-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2020-09-04T15:11:40.000Z
#   </lastmodified>
#   <etag>
#    "0dd42650cb58312d36f0b421f39dcccf-2"
#   </etag>
#   <size>
#    27861035
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202009-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2020-10-13T20:06:37.000Z
#   </lastmodified>
#   <etag>
#    "344e86104bea2424f686a32e3a39070c-2"
#   </etag>
#   <size>
#    24341444
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202010-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2020-11-04T13:17:21.000Z
#   </lastmodified>
#   <etag>
#    "073d10b53c12078e60dd5c02e44147cb-2"
#   </etag>
#   <size>
#    17862067
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202011-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2020-12-04T22:32:44.000Z
#   </lastmodified>
#   <etag>
#    "581af35ecf4434be7e06db88a156d35d"
#   </etag>
#   <size>
#    11671826
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202012-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-01-05T13:56:54.000Z
#   </lastmodified>
#   <etag>
#    "975f19f68bcd26448f66b342bf08fa0d"
#   </etag>
#   <size>
#    4839812
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202101-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-02-04T21:52:59.000Z
#   </lastmodified>
#   <etag>
#    "d7b58a2101c69a9bda9ba096945c8397"
#   </etag>
#   <size>
#    3663505
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202102-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-03-10T00:03:24.000Z
#   </lastmodified>
#   <etag>
#    "0880080a58c0f31bc54157ff1db8a9d1"
#   </etag>
#   <size>
#    1906622
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202103-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-04-08T14:28:53.000Z
#   </lastmodified>
#   <etag>
#    "2942dbf457dbbdf00d8d8dc854911fbb"
#   </etag>
#   <size>
#    8019204
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202104-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-05-07T14:52:05.000Z
#   </lastmodified>
#   <etag>
#    "1d8ba1c7bb2352c4e0ddebf792506a05"
#   </etag>
#   <size>
#    11779512
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202105-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-06-11T17:10:18.000Z
#   </lastmodified>
#   <etag>
#    "9c2b9dc3b4b7a3b341f242c0f26987a4-2"
#   </etag>
#   <size>
#    18892952
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202106-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-07-15T23:22:05.000Z
#   </lastmodified>
#   <etag>
#    "62bcfa0947d7e39c299dc4f5e59c8f1b-2"
#   </etag>
#   <size>
#    26516548
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202107-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-08-14T06:06:49.000Z
#   </lastmodified>
#   <etag>
#    "0042b93934a2af77fd46750effe17dc9-2"
#   </etag>
#   <size>
#    29680807
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202108-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-09-08T18:10:46.000Z
#   </lastmodified>
#   <etag>
#    "90b3b4665be43ffc3d45346d48c49ebb-2"
#   </etag>
#   <size>
#    27875242
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202109-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-10-04T17:21:39.000Z
#   </lastmodified>
#   <etag>
#    "479fa5e9cd74feb6d3bbe20fed2188ff-2"
#   </etag>
#   <size>
#    27476580
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202110-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-11-04T19:58:36.000Z
#   </lastmodified>
#   <etag>
#    "eef8798863a6b45c1dd86b1205a491d0-2"
#   </etag>
#   <size>
#    23009069
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202111-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2021-12-08T20:19:04.000Z
#   </lastmodified>
#   <etag>
#    "f7ef4b9864f055cac384b0888cd43374"
#   </etag>
#   <size>
#    13824532
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202112-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-01-06T16:18:45.000Z
#   </lastmodified>
#   <etag>
#    "b1f504c0a4fecb0514d31d84a24803b7"
#   </etag>
#   <size>
#    9326798
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202201-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-02-02T16:55:22.000Z
#   </lastmodified>
#   <etag>
#    "356a4945f5fdbd8ffe82ddd3c9447eca"
#   </etag>
#   <size>
#    3837661
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202202-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-03-02T20:22:47.000Z
#   </lastmodified>
#   <etag>
#    "77518d1d84f282cc66863e33be4f6763"
#   </etag>
#   <size>
#    4304708
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202203-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-04-06T17:07:41.000Z
#   </lastmodified>
#   <etag>
#    "9363df607888bf8c2d2d3d75d616f24b"
#   </etag>
#   <size>
#    10385621
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202204-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-05-03T16:33:19.000Z
#   </lastmodified>
#   <etag>
#    "c819bb1bea3eebf2eff6cabdb63e18e0"
#   </etag>
#   <size>
#    13362492
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202205-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-06-04T02:08:02.000Z
#   </lastmodified>
#   <etag>
#    "756dca7c4aeccfbbc6e449e8e872499d-2"
#   </etag>
#   <size>
#    22678035
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202206-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-07-15T15:27:59.000Z
#   </lastmodified>
#   <etag>
#    "e55ca9a8d5b10e82c046fa42dfd72720-2"
#   </etag>
#   <size>
#    26903847
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202207-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-08-05T22:27:33.000Z
#   </lastmodified>
#   <etag>
#    "8c002ebdbbfb0edc6a075703becf9247-2"
#   </etag>
#   <size>
#    29511217
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202208-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-09-08T22:20:19.000Z
#   </lastmodified>
#   <etag>
#    "e6004ecc0bcf926c2c31d974a244f13a-2"
#   </etag>
#   <size>
#    27127185
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    202209-divvy-tripdata.zip
#   </key>
#   <lastmodified>
#    2022-10-11T15:59:39.000Z
#   </lastmodified>
#   <etag>
#    "c3f96a976a6d4f9f3afd64c9c3886217-2"
#   </etag>
#   <size>
#    25305434
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Stations_Trips_2013.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:43.000Z
#   </lastmodified>
#   <etag>
#    "c100d30f03e4d358c3f6603f611805c4"
#   </etag>
#   <size>
#    14626914
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Stations_Trips_2014_Q1Q2.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:40.000Z
#   </lastmodified>
#   <etag>
#    "18b84bc29277f1dd2f757fe1cd5a8047-2"
#   </etag>
#   <size>
#    17997624
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Stations_Trips_2014_Q3Q4.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:40.000Z
#   </lastmodified>
#   <etag>
#    "9ca6ee678824480335434b686aaf48f2-2"
#   </etag>
#   <size>
#    30838872
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2015-Q1Q2.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:40.000Z
#   </lastmodified>
#   <etag>
#    "2e4b05891aff6913e9819caf43572c18-2"
#   </etag>
#   <size>
#    22449725
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2015_Q3Q4.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:40.000Z
#   </lastmodified>
#   <etag>
#    "965c8ba274fdc7655f811d56ec71d7df-3"
#   </etag>
#   <size>
#    43624437
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2016_Q1Q2.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:44.000Z
#   </lastmodified>
#   <etag>
#    "05471344e26faa532129bba82490c9e1-2"
#   </etag>
#   <size>
#    30964697
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2016_Q3Q4.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:45.000Z
#   </lastmodified>
#   <etag>
#    "83b98adbcce5e245d39c041cce188b7a-4"
#   </etag>
#   <size>
#    57215032
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2017_Q1Q2.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:48.000Z
#   </lastmodified>
#   <etag>
#    "19dcb290c0295a6e18aa3bf2bf6565f8-3"
#   </etag>
#   <size>
#    42028390
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2017_Q3Q4.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:50.000Z
#   </lastmodified>
#   <etag>
#    "2958de039c43a02ba63e1e26fb593c6f-4"
#   </etag>
#   <size>
#    57495251
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2018_Q1.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:56.000Z
#   </lastmodified>
#   <etag>
#    "61d1a258ecd2595ed764608c15f82b83"
#   </etag>
#   <size>
#    10031818
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2018_Q2.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:07:57.000Z
#   </lastmodified>
#   <etag>
#    "bc6b8507b5470c12368c1fc08147f03a-2"
#   </etag>
#   <size>
#    27175217
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2018_Q3.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:08:00.000Z
#   </lastmodified>
#   <etag>
#    "249018f88c4a06106eef33a70acbdfb8-3"
#   </etag>
#   <size>
#    38779477
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2018_Q4.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:08:05.000Z
#   </lastmodified>
#   <etag>
#    "99750d2b60e7a511e673ceaa7c291ddb"
#   </etag>
#   <size>
#    16721104
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2019_Q1.zip
#   </key>
#   <lastmodified>
#    2021-11-08T22:05:26.000Z
#   </lastmodified>
#   <etag>
#    "39dbd712241f1e4f8ed792b78e1f1302"
#   </etag>
#   <size>
#    9565886
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2019_Q2.zip
#   </key>
#   <lastmodified>
#    2021-11-08T22:06:12.000Z
#   </lastmodified>
#   <etag>
#    "652056546f37ad0f2d4061eb2f939496-2"
#   </etag>
#   <size>
#    28718468
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2019_Q3.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:08:06.000Z
#   </lastmodified>
#   <etag>
#    "fcd3f8a6678ebad736dc9b46da4977c4-3"
#   </etag>
#   <size>
#    42361393
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2019_Q4.zip
#   </key>
#   <lastmodified>
#    2020-01-24T16:08:07.000Z
#   </lastmodified>
#   <etag>
#    "64fea8850eab816a5bf56292a8e49938-2"
#   </etag>
#   <size>
#    18404594
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    Divvy_Trips_2020_Q1.zip
#   </key>
#   <lastmodified>
#    2020-05-27T00:17:43.000Z
#   </lastmodified>
#   <etag>
#    "a0fe9d87d4fac7f8bb8ff0863b5a9f5e"
#   </etag>
#   <size>
#    15920655
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
#  <contents>
#   <key>
#    index.html
#   </key>
#   <lastmodified>
#    2020-01-24T16:08:07.000Z
#   </lastmodified>
#   <etag>
#    "0a0a71d28229db9a3ddd27b9c9ca1f10"
#   </etag>
#   <size>
#    6430
#   </size>
#   <storageclass>
#    STANDARD
#   </storageclass>
#  </contents>
# </listbucketresult>

# %%
zip_keys = soup.findAll('key')
len(zip_keys)
# Out:
# 49

# %% [markdown]
# ### Loop through Keys and only keep divvy-tripdata

# %%
key_ls = []

for i in range(len(zip_keys)):
    key_ls.append(zip_keys[i].text)

key_ls_clean = [ x for x in key_ls if "divvy-tripdata" in x ]

key_ls_clean
# Out:
# ['202004-divvy-tripdata.zip',
#  '202005-divvy-tripdata.zip',
#  '202006-divvy-tripdata.zip',
#  '202007-divvy-tripdata.zip',
#  '202008-divvy-tripdata.zip',
#  '202009-divvy-tripdata.zip',
#  '202010-divvy-tripdata.zip',
#  '202011-divvy-tripdata.zip',
#  '202012-divvy-tripdata.zip',
#  '202101-divvy-tripdata.zip',
#  '202102-divvy-tripdata.zip',
#  '202103-divvy-tripdata.zip',
#  '202104-divvy-tripdata.zip',
#  '202105-divvy-tripdata.zip',
#  '202106-divvy-tripdata.zip',
#  '202107-divvy-tripdata.zip',
#  '202108-divvy-tripdata.zip',
#  '202109-divvy-tripdata.zip',
#  '202110-divvy-tripdata.zip',
#  '202111-divvy-tripdata.zip',
#  '202112-divvy-tripdata.zip',
#  '202201-divvy-tripdata.zip',
#  '202202-divvy-tripdata.zip',
#  '202203-divvy-tripdata.zip',
#  '202204-divvy-tripdata.zip',
#  '202205-divvy-tripdata.zip',
#  '202206-divvy-tripdata.zip',
#  '202207-divvy-tripdata.zip',
#  '202208-divvy-tripdata.zip',
#  '202209-divvy-tripdata.zip']

# %%
key_ls_clean[27:]
# Out:
# ['202207-divvy-tripdata.zip',
#  '202208-divvy-tripdata.zip',
#  '202209-divvy-tripdata.zip']

# %% [markdown]
# ### Pull and save all files

# %%
for zip_f in key_ls_clean[27:]:
    r = requests.get(f"https://divvy-tripdata.s3.amazonaws.com/{zip_f}")
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall(SAVE_FILES)

# %%
import os

file_ls = []

for file in os.listdir(SAVE_FILES):
    if file.endswith(".csv"):
        file_ls.append(os.path.join(SAVE_FILES, file))
    
file_ls
# Out:
# ['C:\\Users\\Nicholas\\Desktop\\Masters - Classes\\MSDS436\\Final\\DATA\\202207-divvy-tripdata.csv',
#  'C:\\Users\\Nicholas\\Desktop\\Masters - Classes\\MSDS436\\Final\\DATA\\202208-divvy-tripdata.csv',
#  'C:\\Users\\Nicholas\\Desktop\\Masters - Classes\\MSDS436\\Final\\DATA\\202209-divvy-publictripdata.csv']

# %%
df_dict = {}

for i in file_ls:
    for num in range(len(file_ls)):
        df = pd.read_csv(i)
        df_dict[f"df_{num}"] = df

# %%
df_dict.keys()
# Out:
# dict_keys(['df_0', 'df_1', 'df_2'])

# %%
dict_keys_ls = list(df_dict.keys())
df_dict[dict_keys_ls[1]]
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       5156990AC19CA285  electric_bike  2022-09-01 08:36:22
# 1       E12D4A16BF51C274  electric_bike  2022-09-01 17:11:29
# 2       A02B53CD7DB72DD7  electric_bike  2022-09-01 17:15:50
# 3       C82E05FEE872DF11  electric_bike  2022-09-01 09:00:28
# 4       4DEEB4550A266AE1  electric_bike  2022-09-01 07:30:11
# ...                  ...            ...                  ...
# 701334  32ECA2B32C4B6F85   classic_bike  2022-09-05 17:59:21
# 701335  14801F713026AEAE   classic_bike  2022-09-30 17:20:54
# 701336  7CCAF5D6E88E45C0  electric_bike  2022-09-04 11:39:37
# 701337  AF9A129D9AFAA40B  electric_bike  2022-09-28 13:42:45
# 701338  60B56F4897429FCE  electric_bike  2022-09-01 20:07:04
#
#                    ended_at       start_station_name start_station_id  \
# 0       2022-09-01 08:39:05                      NaN              NaN
# 1       2022-09-01 17:14:45                      NaN              NaN
# 2       2022-09-01 17:16:12                      NaN              NaN
# 3       2022-09-01 09:10:32                      NaN              NaN
# 4       2022-09-01 07:32:36                      NaN              NaN
# ...                     ...                      ...              ...
# 701334  2022-09-05 18:19:07  Lincoln Ave & Winona St     KA1504000078
# 701335  2022-09-30 17:34:40     Broadway & Ridge Ave            15578
# 701336  2022-09-04 11:50:55     Broadway & Ridge Ave            15578
# 701337  2022-09-28 13:52:59  Lincoln Ave & Winona St     KA1504000078
# 701338  2022-09-01 20:18:01  Lincoln Ave & Winona St     KA1504000078
#
#                                          end_station_name end_station_id  \
# 0                          California Ave & Milwaukee Ave          13084
# 1                                                     NaN            NaN
# 2                                                     NaN            NaN
# 3                                                     NaN            NaN
# 4                                                     NaN            NaN
# ...                                                   ...            ...
# 701334  Broadway & Wilson - Truman College Vaccination...          13074
# 701335  Broadway & Wilson - Truman College Vaccination...          13074
# 701336  Broadway & Wilson - Truman College Vaccination...          13074
# 701337  Broadway & Wilson - Truman College Vaccination...          13074
# 701338  Broadway & Wilson - Truman College Vaccination...          13074
#
#         start_lat  start_lng    end_lat    end_lng member_casual
# 0       41.930000 -87.690000  41.922695 -87.697153        casual
# 1       41.870000 -87.620000  41.870000 -87.620000        casual
# 2       41.870000 -87.620000  41.870000 -87.620000        casual
# 3       41.930000 -87.690000  41.940000 -87.670000        casual
# 4       41.920000 -87.730000  41.920000 -87.730000        casual
# ...           ...        ...        ...        ...           ...
# 701334  41.974911 -87.692503  41.965221 -87.658139        member
# 701335  41.984045 -87.660274  41.965221 -87.658139        member
# 701336  41.984112 -87.660269  41.965221 -87.658139        member
# 701337  41.974921 -87.692735  41.965221 -87.658139        member
# 701338  41.974902 -87.692650  41.965221 -87.658139        member
#
# [701339 rows x 13 columns]

# %%
# Stack data frames
Q3_df = pd.concat([df_dict[dict_keys_ls[0]], df_dict[dict_keys_ls[1]], df_dict[dict_keys_ls[2]]], ignore_index=True, axis=0)

# %%
Q3_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  5156990AC19CA285  electric_bike  2022-09-01 08:36:22  2022-09-01 08:39:05
# 1  E12D4A16BF51C274  electric_bike  2022-09-01 17:11:29  2022-09-01 17:14:45
# 2  A02B53CD7DB72DD7  electric_bike  2022-09-01 17:15:50  2022-09-01 17:16:12
# 3  C82E05FEE872DF11  electric_bike  2022-09-01 09:00:28  2022-09-01 09:10:32
# 4  4DEEB4550A266AE1  electric_bike  2022-09-01 07:30:11  2022-09-01 07:32:36
#
#   start_station_name start_station_id                end_station_name  \
# 0                NaN              NaN  California Ave & Milwaukee Ave
# 1                NaN              NaN                             NaN
# 2                NaN              NaN                             NaN
# 3                NaN              NaN                             NaN
# 4                NaN              NaN                             NaN
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# 0          13084      41.93     -87.69  41.922695 -87.697153        casual
# 1            NaN      41.87     -87.62  41.870000 -87.620000        casual
# 2            NaN      41.87     -87.62  41.870000 -87.620000        casual
# 3            NaN      41.93     -87.69  41.940000 -87.670000        casual
# 4            NaN      41.92     -87.73  41.920000 -87.730000        casual

# %%
Q3_df.to_csv("2022Q3_divvy-tripdata.csv")

# %% [markdown]
# ### Save data in AWS S3 Bucket
